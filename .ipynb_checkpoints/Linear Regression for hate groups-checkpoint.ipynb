# 7           Yes       NaN  2018
# 8           Yes       NaN  2018
# 9           Yes       NaN  2018
# 10          NaN       NaN  2018
# 11          Yes       NaN  2018
# 12          Yes       NaN  2018
# 13          Yes       NaN  2018
# 14          Yes       NaN  2018
# 15          Yes       NaN  2018
# 16          Yes       NaN  2018
# 17          Yes       NaN  2018
# 18          Yes       NaN  2018
# 19          Yes       NaN  2018
# 20          Yes       NaN  2018
# 21          Yes       NaN  2018
# 22          Yes       NaN  2018
# 23          Yes       NaN  2018
# 24          Yes       NaN  2018
# 25          Yes       NaN  2018
# 26          NaN       NaN  2018
# 27          NaN       NaN  2018
# 28          Yes       NaN  2018
# 29          NaN       NaN  2018

# %%
df_2014 = pd.read_csv("splc-hate-groups-2014.csv")
df_2014.head(30)
# Out:
#                                                 Title                City  \
# 0                         11th Hour Remnant Messenger            Santa Fe
# 1                                    a2z Publications           Las Vegas
# 2                            Abiding Truth Ministries         Springfield
# 3                              Advanced White Society  Pemberton Township
# 4                             Aggressive Christianity          Fence Lake
# 5                         All Eyes on Egypt Bookstore       Milledgeville
# 6                     Alliance for Catholic Tradition      Pleasant Unity
# 7                                   Alternative Right             Atlanta
# 8                        America's Promise Ministries           Sandpoint
# 9                              American Border Patrol        Sierra Vista
# 10                  American College of Pediatricians         Gainesville
# 11                        The American Defence League            New York
# 12                        American Family Association              Tupelo
# 13                                American Free Press          Washington
# 14                American Freedom Defense Initiative            New York
# 15                                     American Front          Sacramento
# 16  American Immigration Control Foundation/Americ...            Monterey
# 17                         American Nationalist Union           Las Vegas
# 18                                American Nazi Party            Westland
# 19        American Renaissance/New Century Foundation              Oakton
# 20                                    American Vision      Powder Springs
# 21            Americans for Truth About Homosexuality          Naperville
# 22                          Americans Have Had Enough             Mauldin
# 23                                 Artisan Publishers            Muskogee
# 24                   Aryan Nations Knights of the KKK            Converse
# 25                                      Aryan Nations            Converse
# 26                                      Aryan Nations          Bainbridge
# 27                                  Aryan Strikeforce          Somerville
# 28                                         Aryan Wear              Keller
# 29                                         As-Sabiqun          Washington
#
#                    State                                   Group  \
# 0             New Mexico                                     NaN
# 1                 Nevada                                     NaN
# 2          Massachusetts                                     NaN
# 3             New Jersey                                     NaN
# 4             New Mexico                                     NaN
# 5                Georgia                                     NaN
# 6           Pennsylvania                                     NaN
# 7                Georgia                                     NaN
# 8                  Idaho            America's Promise Ministries
# 9                Arizona  American Border Patrol/American Patrol
# 10               Florida       American College of Pediatricians
# 11              New York                                     NaN
# 12           Mississippi             American Family Association
# 13  District of Columbia                                     NaN
# 14              New York                                     NaN
# 15            California                                     NaN
# 16              Virginia                                     NaN
# 17                Nevada                                     NaN
# 18              Michigan                                     NaN
# 19              Virginia                    American Renaissance
# 20               Georgia                                     NaN
# 21              Illinois                                     NaN
# 22        South Carolina                                     NaN
# 23              Oklahoma                                     NaN
# 24             Louisiana                                     NaN
# 25             Louisiana                                     NaN
# 26                  Ohio                                     NaN
# 27            New Jersey                                     NaN
# 28                 Texas                                     NaN
# 29  District of Columbia                                     NaN
#
#                            Ideology  Headquarters Statewide  Year
# 0                Christian Identity           NaN       NaN  2014
# 1                      General Hate           NaN       NaN  2014
# 2                         Anti-LGBT           NaN       NaN  2014
# 3                 White Nationalist           NaN       NaN  2014
# 4                      General Hate           NaN       NaN  2014
# 5                 Black Nationalist           NaN       NaN  2014
# 6   Radical Traditional Catholicism           NaN       NaN  2014
# 7                 White Nationalist           NaN       NaN  2014
# 8                Christian Identity           NaN       NaN  2014
# 9                    Anti-Immigrant           NaN       NaN  2014
# 10                        Anti-LGBT           NaN       NaN  2014
# 11                      Anti-Muslim           NaN       NaN  2014
# 12                        Anti-LGBT           NaN       NaN  2014
# 13                     General Hate           NaN       NaN  2014
# 14                      Anti-Muslim           NaN       NaN  2014
# 15                  Racist Skinhead           NaN       NaN  2014
# 16                   Anti-Immigrant           NaN       NaN  2014
# 17                White Nationalist           NaN       NaN  2014
# 18                         Neo-Nazi           NaN       NaN  2014
# 19                White Nationalist           NaN       NaN  2014
# 20                        Anti-LGBT           NaN       NaN  2014
# 21                        Anti-LGBT           NaN       NaN  2014
# 22                   Anti-Immigrant           NaN       NaN  2014
# 23                     General Hate           NaN       NaN  2014
# 24                     Ku Klux Klan           NaN       NaN  2014
# 25                         Neo-Nazi           NaN       NaN  2014
# 26                         Neo-Nazi           NaN       NaN  2014
# 27                  Racist Skinhead           NaN       NaN  2014
# 28                White Nationalist           NaN       NaN  2014
# 29                     General Hate           NaN       NaN  2014

# %%
number_hate_groups = pd.read_csv("groups_per_year.csv")

# %%
number_hate_groups
# Out:
#     year  number
# 0   2000     457
# 1   2001     602
# 2   2002     676
# 3   2003     708
# 4   2004     751
# 5   2005     803
# 6   2006     844
# 7   2007     888
# 8   2008     926
# 9   2009     932
# 10  2010    1002
# 11  2011    1018
# 12  2012    1007
# 13  2013     939
# 14  2014     784
# 15  2015     892
# 16  2016     917
# 17  2017     954
# 18  2018    1020

# %%
# dataset.plot(x='MinTemp', y='MaxTemp', style='o')  
# plt.title('MinTemp vs MaxTemp')  
# plt.xlabel('MinTemp')  
# plt.ylabel('MaxTemp')  
# plt.show()

# %%
X = number_hate_groups[['year']]
y = number_hate_groups.number
reg = LinearRegression().fit(X,y)
reg.coef_, reg.intercept_
# Out:
# (array([21.41754386]), -42179.424561403495)

# %%
X
# Out:
# array([[2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018]])

# %%
y_predicted = reg.predict(X)

# %%
plt.scatter(X, y,  color='gray')
plt.plot(X, y_predicted, color='red', linewidth=2)
plt.show()

# %%
test_X = np.array([[2000],[2035]])

y_predicted_2035 = reg.predict(test_X)
y_predicted_2035
# Out:
# array([ 655.66315789, 1405.27719298])

# %%
plt.scatter(X, y,  color='gray')
plt.plot(test_X, y_predicted_2035, color='red', linewidth=2)
plt.show()

# %%
np.array([[2000],[2005]]).shape
# Out:
# (2, 1)

# %%
# save data as csv

# %%
# from matplotlib.ticker import StrMethodFormatter
# plt.gca().xaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
# plt.scatter(X, y,  color='gray')
# plt.plot(X, y_predicted, color='red', linewidth=2)
# plt.show()
